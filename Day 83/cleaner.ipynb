# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Top Steam Games.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Current', '24h Peak', 'All-Time Peak'], dtype='object')

# %%
display(df)
# Out:
#     Unnamed: 0                              Name  Current 24h Peak  \
# 0            0  Counter-Strike: Global Offensive  597,501  889,897
# 1            1                            Dota 2  483,971  662,819
# 2            2               PUBG: BATTLEGROUNDS  321,263  498,963
# 3            3                          Lost Ark  256,951  356,506
# 4            4                        ELDEN RING  247,994  339,322
# ..         ...                               ...      ...      ...
# 95          95                   Forza Horizon 5    6,732    9,779
# 96          96      Fall Guys: Ultimate Knockout    6,667   11,093
# 97          97                           F1 2021    6,654   17,714
# 98          98                   Battlefield 1 ™    6,538   10,146
# 99          99              Dyson Sphere Program    6,412    7,042
#
#    All-Time Peak
# 0      1,308,963
# 1      1,295,114
# 2      3,257,248
# 3      1,325,305
# 4        953,426
# ..           ...
# 95        81,096
# ...

# %%
df["Current"] = df["Current"].str.replace(",", "")
df["24h Peak"] = df["24h Peak"].str.replace(",", "")
df["All-Time Peak"] = df["All-Time Peak"].str.replace(",", "")
cleaned_df = df[["Name", "Current", "24h Peak", "All-Time Peak"]]

# %%
display(cleaned_df)
# Out:
#                                 Name Current 24h Peak All-Time Peak
# 0   Counter-Strike: Global Offensive  597501   889897       1308963
# 1                             Dota 2  483971   662819       1295114
# 2                PUBG: BATTLEGROUNDS  321263   498963       3257248
# 3                           Lost Ark  256951   356506       1325305
# 4                         ELDEN RING  247994   339322        953426
# ..                               ...     ...      ...           ...
# 95                   Forza Horizon 5    6732     9779         81096
# 96      Fall Guys: Ultimate Knockout    6667    11093        172213
# 97                           F1 2021    6654    17714         25575
# 98                   Battlefield 1 ™    6538    10146         43322
# 99              Dyson Sphere Program    6412     7042         59815
#
# [100 rows x 4 columns]

# %%
cleaned_df.to_csv("Top 100 Steam Games.csv")
